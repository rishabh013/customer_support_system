# %%
import sys
print(sys.version)
# Out:
# 3.10.8 (v3.10.8:aaaf517424, Oct 11 2022, 10:14:40) [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
import os
os.system("python3 --version")
# Out:
# Python 3.10.8
# 0

# %%
https://astra.datastax.com/org/df2cfef0-2507-41bd-8eef-02d16758c46f/database/cae51edd-c16a-4270-8906-770fd3812488/summary
# Out:
#   Cell In[8], line 1
#     https://astra.datastax.com/org/df2cfef0-2507-41bd-8eef-02d16758c46f/database/cae51edd-c16a-4270-8906-770fd3812488/summary
#                                                   ^
# SyntaxError: invalid decimal literal
